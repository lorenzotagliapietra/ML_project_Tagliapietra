# %% [markdown]
# <a href="https://colab.research.google.com/github/lorenzotagliapietra/ML_project_Tagliapietra/blob/main/Cluster_finder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
# Clustering di Galassie in Diagramma Colore-Magnitudine

Questo notebook implementa una pipeline per identificare galassie compagne attorno a una radiogalassia centrale utilizzando metodi di clustering non supervisionato nel diagramma colore-magnitudine (CMD).
"""

import numpy as np
import pandas as pd
# !pip install matplotlib==3.10.0
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import confusion_matrix, precision_score, recall_score
import seaborn as sns

from astropy.stats import sigma_clip
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy import units as u

from matplotlib.colors import to_rgba


# !pip install adjustText
from adjustText import adjust_text

# Configurazione grafica
try:
    plt.style.use('seaborn-v0_8')
except:
    plt.style.use('ggplot')  # Fallback a un altro stile disponibile
sns.set_palette("colorblind")
# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib==3.10.0 in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.0) (1.17.0)
# Requirement already satisfied: adjustText in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from adjustText) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from adjustText) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from adjustText) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Base directory
base_path = '/content/drive/MyDrive/environment_redsequence/'

# Dizionario con tutti i file per ogni campo
file_paths = {
    'J082729_73': {
        'all': 'crossSDSS.fits',
        'galaxies': 'galaxiesSDSS.fits',
        'ellipticals': 'ellipSDSS.fits',
    },
    'J082603_81': {
        'all': 'crossSDSS.fits',
        'galaxies': 'galaxiesSDSS.fits',
        'ellipticals': 'ellipSDSS.fits',
    }
}

# Scegli il campo
target_field = 'J082729_73'


# Funzione per caricare i dati
def load_fits_to_dataframe(path):
    with fits.open(path) as hdul:
        data = hdul[1].data
        return pd.DataFrame(data)

# Funzione per filtrare i dati -> controllo l'errore relativo e punti che si allontanano troppo dalla redsequence
def filter_by_mag_errors(df):
    required_cols = ['imag', 'e_imag', 'rmag', 'e_rmag']
    if not all(col in df.columns for col in required_cols):
        raise ValueError(f"Il DataFrame deve contenere le colonne: {required_cols}")
    imag_error_ratio = df['e_imag'] / df['imag']
    rmag_error_ratio = df['e_rmag'] / df['rmag']
    r_i = df['rmag'] - df['imag']
    filtered = df[(imag_error_ratio < 0.5) & (rmag_error_ratio < 0.5) & (r_i < 3.0) & (r_i > -3.0)]
    print(f"Filtrati {len(df) - len(filtered)} oggetti ({(len(df) - len(filtered))/len(df)*100:.1f}%) con errori > 20% o colori estremi")
    return filtered

# Percorso alla cartella selezionata
field_path = base_path + target_field + '/'

# Caricamento dati
print(f"\n📁 Caricamento dati per il campo: {target_field}")
all_objects = load_fits_to_dataframe(field_path + file_paths[target_field]['all'])
all_objects = filter_by_mag_errors(all_objects)

galaxies = load_fits_to_dataframe(field_path + file_paths[target_field]['galaxies'])
galaxies = filter_by_mag_errors(galaxies)

ellipticals = load_fits_to_dataframe(field_path + file_paths[target_field]['ellipticals'])
ellipticals = filter_by_mag_errors(ellipticals)



# Info riepilogativa
print("Riepilogo:")
print(f"Tutti gli oggetti: {len(all_objects)}")
print(f"Galassie: {len(galaxies)}")
print(f"Ellittiche: {len(ellipticals)}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📁 Caricamento dati per il campo: J082729_73
# Filtrati 10 oggetti (0.3%) con errori > 20% o colori estremi
# Filtrati 2 oggetti (0.2%) con errori > 20% o colori estremi
# Filtrati 0 oggetti (0.0%) con errori > 20% o colori estremi
# Riepilogo:
# Tutti gli oggetti: 3055
# Galassie: 819
# Ellittiche: 38

# %%
def find_target(all_objects, galaxies, ellipticals, angsep=None):
    """Trova l'oggetto target: per angsep oppure con minima separazione comune nei 3 cataloghi"""

    if angsep is not None:
        # Cerca l'oggetto con angsep esattamente uguale (o quasi)
        match = np.isclose(all_objects['angsep'], angsep, rtol=0, atol=1e-13)
        if match.any():
            target = all_objects[match].iloc[0]
        else:
            raise ValueError(f"Nessun oggetto trovato con angsep ≈ {angsep}")
    else:
        # Trova gli ID comuni
        common_ids = set(all_objects['SDSS9']).intersection(galaxies['SDSS9']).intersection(ellipticals['SDSS9'])

        # Filtra gli oggetti comuni
        common_all = all_objects[all_objects['SDSS9'].isin(common_ids)]

        if common_all.empty:
            raise ValueError("Nessun oggetto comune nei tre cataloghi con colonna 'SDSS9'")

        # Trova quello con minima angsep
        target = common_all.loc[common_all['angsep'].idxmin()]

    return target


# Trova e mostra l'oggetto target
target = find_target(all_objects, galaxies, ellipticals)
print("\nOggetto target identificato:")
print(f"ID: {target['SDSS9']}, angsep: {target['angsep']:.4f}")
print(f"Coordinate: RA={target['RAJ2000']}, DEC={target['DEJ2000']}")
print(f"Magnitudini: r={target['rmag']:.2f}, i={target['imag']:.2f}")

#Redshift del target
z_RG = target['zsrc']

print(f"Redshift del target: {z_RG}")
# Out:
# Oggetto target identificato:
# ID: J082723.61+530834.4, angsep: 82.1773
# Coordinate: RA=126.848389, DEC=53.142894
# Magnitudini: r=17.61, i=17.09
# Redshift del target: 0.11900000274181366

# %%
def plot_cmd(data, title, ax=None, color='b', alpha=0.5, target=None):
    """Plot del diagramma colore-magnitudine"""
    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 8))

    # Plot dei punti principali
    ax.scatter(data['imag'], data['rmag'] - data['imag'],
               c=color, alpha=alpha, s=10, label=title)

    # Aggiungi target se specificato
    if target is not None:
        target_x = target['imag']
        target_y = target['rmag'] - target['imag']
        ax.scatter(target_x, target_y, s=300, marker='*',
                  color='gold', edgecolor='black', linewidth=1,
                  label='Target', zorder=10)

    ax.set_xlabel('Magnitude (i)', fontsize=17)
    ax.set_ylabel('Colour (r - i)', fontsize=17)
    ax.set_title(title, fontsize=20)
    ax.set_facecolor("white")
    ax.grid(c='lightgray')

    # Aggiungi legenda se c'è il target
    if target is not None:
        ax.legend(prop={'size': 14})

    return ax

# Plot per i tre cataloghi con target
fig, axes = plt.subplots(1, 3, figsize=(24, 8))
plot_cmd(all_objects, "Tutti gli oggetti", axes[0], color='b', target=target)
plot_cmd(galaxies, "Galassie", axes[1], color='g', target=target)
plot_cmd(ellipticals, "Galassie ellittiche", axes[2], color='r', target=target)
plt.tight_layout()
plt.show()

fig, ax_un = plt.subplots(figsize=(12,10))
plot_cmd(galaxies, "Galaxies", ax=ax_un, color='b', target=target)
plt.show()

# %%
def fit_gmm(data, n_components=2, plot=True, target=None, ellipticals=None):
    """Applica GMM ai dati e visualizza i risultati con ellissi (1-2-3σ) colorate per cluster"""

    # Prepara i dati (i, r-i)
    X = np.column_stack([data['imag'], data['rmag'] - data['imag']])
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Fit GMM
    gmm = GaussianMixture(n_components=n_components, covariance_type='full', random_state=42)
    gmm.fit(X_scaled)
    labels = gmm.predict(X_scaled)
    probs = gmm.predict_proba(X_scaled)
    bic = gmm.bic(X_scaled)
    aic = gmm.aic(X_scaled)

    # Maschera per ellittiche (se disponibili)
    ell_mask = data['SDSS9'].isin(ellipticals['SDSS9']) if ellipticals is not None else np.zeros(len(data), dtype=bool)

    # Identifica il cluster del target (se disponibile)
    target_cluster_id = None
    if target is not None and 'SDSS9' in data.columns:
        match = data['SDSS9'] == target['SDSS9']
        if match.any():
            target_idx = match.idxmax()
            target_cluster_id = labels[data.index.get_loc(target_idx)]

    # Conta ellittiche nel cluster del target
    if target_cluster_id is not None:
        in_target_cluster = labels == target_cluster_id
        n_ellipticals_in_target_cluster = np.sum(in_target_cluster & ell_mask)
        print(f"→ Ellittiche nel cluster del target (Cluster {target_cluster_id}): {n_ellipticals_in_target_cluster}")
    else:
        n_ellipticals_in_target_cluster = 0
        print("⚠️ Target non assegnato a nessun cluster.")

    if plot:
        fig, ax = plt.subplots(figsize=(12, 10))

        for i in range(n_components):
            cluster_mask = labels == i
            color = f'C{i}'

            # Normali
            normal_mask = cluster_mask & ~ell_mask
            ax.scatter(X[normal_mask, 0], X[normal_mask, 1], s=10, alpha=0.6, color=color, label=f'Cluster {i}')

            # Ellittiche evidenziate
            elli_mask = cluster_mask & ell_mask
            ax.scatter(X[elli_mask, 0], X[elli_mask, 1], s=60, alpha=0.9, marker='o',
                       edgecolor='black', linewidths=1.2, facecolor=color, label=f'Ellipticals in cluster {i}')

            # Parametri della gaussiana
            mean = scaler.inverse_transform(gmm.means_[i].reshape(1, -1)).flatten()
            if gmm.covariance_type == 'full':
                cov_scaled = gmm.covariances_[i]
                cov = np.diag(scaler.scale_) @ cov_scaled @ np.diag(scaler.scale_)
            else:
                cov = np.eye(2)

            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            eigenvalues = np.where(eigenvalues < 0, 0, eigenvalues)
            angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigenvalues + 1e-8)

            # Ellissi 1σ, 2σ, 3σ
            for sigma, linestyle in zip([1, 2], ['solid', 'dashed']):
                ell = Ellipse(mean,
                              width * sigma,
                              height * sigma,
                              angle=angle,
                              edgecolor=color,
                              facecolor='none',
                              linewidth=2,
                              linestyle=linestyle)
                ax.add_patch(ell)

            # Centro gaussiana
            ax.scatter(mean[0], mean[1], c='k', marker='x', s=80)

        # Target
        if target is not None:
            tx = target['imag']
            ty = target['rmag'] - target['imag']
            ax.scatter(tx, ty, s=250, marker='*', color='gold',
                       edgecolor='black', linewidth=1.5, label='Target', zorder=10)

        ax.set_xlabel('Magnitude (i)', fontsize=14)
        ax.set_ylabel('Colour (r - i)', fontsize=14)
        ax.set_title(f'GMM clustering with {n_components} components', fontsize=16)
        ax.set_facecolor("white")
        ax.legend(loc='best')
        ax.grid(c = 'lightgray')
        plt.tight_layout()
        plt.show()

    return gmm, labels, probs, bic, aic, n_ellipticals_in_target_cluster

# %%
def apply_dbscan(data, eps=0.07, min_samples=5, ellipticals=None, target=None, show_redshifts=False):
    """Applica DBSCAN alle coordinate RA/Dec e mostra i cluster con ellittiche"""

    coords = data[['RAJ2000', 'DEJ2000']].values
    coords_scaled = StandardScaler().fit_transform(coords)

    db = DBSCAN(eps=eps, min_samples=min_samples).fit(coords_scaled)
    labels = db.labels_

    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

    # Trova il cluster del target (se specificato)
    target_cluster_id = None
    if target is not None and 'SDSS9' in data.columns:
      match = data['SDSS9'] == target['SDSS9']
      if match.any():
        target_idx = match.idxmax()
        iloc_pos = data.index.get_loc(target_idx)
        target_cluster_id = labels[iloc_pos]

    # Inizializza conteggi
    ellipses_in_target_cluster = 0
    clusters_with_ellipticals = {}

    # Plot
    plt.figure(figsize=(12,10))

    # Rumore
    noise_mask = labels == -1
    plt.scatter(data['RAJ2000'][noise_mask], data['DEJ2000'][noise_mask],
                c='gray', alpha=0.3, s=10, label='Rumore')
    # Etichette per i punti nel rumore
    if show_redshifts and 'zsp' in data.columns:
        texts_nois = []
        for i in data[noise_mask & data['zsp'].notna()].index:

            ra = data.at[i, 'RAJ2000']
            dec = data.at[i, 'DEJ2000']
            z_val = data.at[i, 'zsp']
            texts_nois.append(plt.text(ra, dec, f"{z_val:.3f}", fontsize=8, color='gray'))
        adjust_text(texts_nois, arrowprops=dict(arrowstyle='->', color='black'))

    # Ciclo sui cluster
    for cluster_id in sorted(set(labels)):
        if cluster_id == -1:
            continue

        cluster_mask = labels == cluster_id
        color = f'C{cluster_id % 10}'

        # Controlla ellittiche nel cluster
        ell_mask = cluster_mask & data['SDSS9'].isin(ellipticals['SDSS9']) if ellipticals is not None else np.zeros(len(data), dtype=bool)

        if ell_mask.any():
            # Salva info per legenda
            clusters_with_ellipticals[cluster_id] = {
                'color': color,
                'ra': data['RAJ2000'][ell_mask],
                'dec': data['DEJ2000'][ell_mask]
            }

            if cluster_id == target_cluster_id:
                ellipses_in_target_cluster = ell_mask.sum()

        # Etichette dei redshift
        if show_redshifts and 'zsp' in data.columns:
          texts_clus=[]
          for i in data[cluster_mask & data['zsp'].notna()].index:
            ra = data.at[i, 'RAJ2000']
            dec = data.at[i, 'DEJ2000']
            z_val = data.at[i, 'zsp']
            texts_clus.append(plt.text(ra, dec, f"{z_val:.3f}", fontsize=7, color='darkgray'))
          adjust_text(texts_clus, arrowprops=dict(arrowstyle='->', color='black'))

        # Disegna comunque tutti i punti (senza etichetta)
        plt.scatter(data['RAJ2000'][cluster_mask], data['DEJ2000'][cluster_mask],
                    s=20, alpha=0.7, color=color)

    # Disegna solo i cluster con ellittiche nella legenda
    for cluster_id in sorted(clusters_with_ellipticals, key=lambda x: x != target_cluster_id):
        info = clusters_with_ellipticals[cluster_id]
        label = f"Ellittiche - Cluster {cluster_id}"
        if cluster_id == target_cluster_id:
            label += " (principale)"
            main_cluster_mask = labels == cluster_id


        plt.scatter(info['ra'], info['dec'], s=60, alpha=0.9, marker='o',
                       edgecolor='black', linewidths=1.2, color=info['color'], label=label)

    # Target
    if target is not None:
        plt.scatter(target['RAJ2000'], target['DEJ2000'],
                    marker='*', s=300, color='gold', edgecolor='black',
                    linewidth=1.5, label='Target')

    # Titolo e legenda compatta
    plt.xlabel('RA (deg)', fontsize=14)
    plt.ylabel('Dec (deg)', fontsize=14)
    plt.title(f'DBSCAN clustering (eps={eps}, min_samples={min_samples})', fontsize=16)
    plt.gca().set_facecolor('white')
    plt.gcf().set_facecolor('white')
    plt.legend(loc='upper right', title='Legenda')
    plt.grid(c='lightgray')
    plt.tight_layout()

    # Stampa riassuntiva
    print(f"\nCluster del target: {target_cluster_id}")
    if target_cluster_id != -1:
        print(f"→ Numero membri nel cluster del target: {(labels == target_cluster_id).sum()}")
        print(f"→ Ellittiche nel cluster del target: {ellipses_in_target_cluster}")
    else:
        print("Il target è etichettato come rumore (cluster -1)")

    other_clusters = [cid for cid in clusters_with_ellipticals if cid != target_cluster_id]
    if other_clusters:
        print(f"Cluster con almeno un'ellittica (escluso il target): {other_clusters}")
    else:
        print("Nessun altro cluster contiene galassie ellittiche")

    return labels, main_cluster_mask

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

def apply_dbscan(data, eps=0.07, min_samples=5, ellipticals=None, target=None, show_redshifts=False):
    """Applica DBSCAN alle coordinate RA/Dec e mostra i cluster con ellittiche usando colori distinti"""

    coords = data[['RAJ2000', 'DEJ2000']].values
    coords_scaled = StandardScaler().fit_transform(coords)

    db = DBSCAN(eps=eps, min_samples=min_samples).fit(coords_scaled)
    labels = db.labels_

    unique_labels = sorted(set(labels))
    n_clusters = len(unique_labels) - (1 if -1 in labels else 0)

    # Mappa dei colori per cluster (evita modulo %10)
    cmap = cm.get_cmap('nipy_spectral', 256)
    norm = mcolors.Normalize(vmin=min(l for l in unique_labels if l != -1),
                             vmax=max(unique_labels))

    cluster_colors = {label: 'gray' if label == -1 else cmap(norm(label)) for label in unique_labels}

    # Trova il cluster del target
    target_cluster_id = None
    if target is not None and 'SDSS9' in data.columns:
        match = data['SDSS9'] == target['SDSS9']
        if match.any():
            target_idx = match.idxmax()
            iloc_pos = data.index.get_loc(target_idx)
            target_cluster_id = labels[iloc_pos]

    ellipses_in_target_cluster = 0
    clusters_with_ellipticals = {}

    plt.figure(figsize=(12, 10))

    # Rumore
    noise_mask = labels == -1
    plt.scatter(data['RAJ2000'][noise_mask], data['DEJ2000'][noise_mask],
                c='gray', alpha=0.3, s=10, label='Rumore')

    # Etichette per i punti nel rumore
    if show_redshifts and 'zsp' in data.columns:
        texts_nois = []
        for i in data[noise_mask & data['zsp'].notna()].index:
            ra = data.at[i, 'RAJ2000']
            dec = data.at[i, 'DEJ2000']
            z_val = data.at[i, 'zsp']
            texts_nois.append(plt.text(ra, dec, f"{z_val:.3f}", fontsize=8, color='gray'))
        adjust_text(texts_nois, arrowprops=dict(arrowstyle='->', color='black'))

    # Ciclo sui cluster
    for cluster_id in unique_labels:
        if cluster_id == -1:
            continue

        cluster_mask = labels == cluster_id
        color = cluster_colors[cluster_id]

        # Controlla ellittiche
        ell_mask = cluster_mask & data['SDSS9'].isin(ellipticals['SDSS9']) if ellipticals is not None else np.zeros(len(data), dtype=bool)

        if ell_mask.any():
            clusters_with_ellipticals[cluster_id] = {
                'color': color,
                'ra': data['RAJ2000'][ell_mask],
                'dec': data['DEJ2000'][ell_mask]
            }

            if cluster_id == target_cluster_id:
                ellipses_in_target_cluster = ell_mask.sum()

        # Etichette dei redshift
        if show_redshifts and 'zsp' in data.columns:
            texts_clus = []
            for i in data[cluster_mask & data['zsp'].notna()].index:
                ra = data.at[i, 'RAJ2000']
                dec = data.at[i, 'DEJ2000']
                z_val = data.at[i, 'zsp']
                texts_clus.append(plt.text(ra, dec, f"{z_val:.3f}", fontsize=7, color='darkgray'))
            adjust_text(texts_clus, arrowprops=dict(arrowstyle='->', color='black'))

        # Disegna i punti del cluster
        plt.scatter(data['RAJ2000'][cluster_mask], data['DEJ2000'][cluster_mask],
                    s=20, alpha=0.7, color=color)

    # Ellittiche evidenziate
    for cluster_id in sorted(clusters_with_ellipticals, key=lambda x: x != target_cluster_id):
        info = clusters_with_ellipticals[cluster_id]
        label = f"Ellittiche - Cluster {cluster_id}"
        if cluster_id == target_cluster_id:
            label += " (principale)"
            main_cluster_mask = labels == cluster_id

        plt.scatter(info['ra'], info['dec'], s=60, alpha=0.9, marker='o',
                    edgecolor='black', linewidths=1.2, color=info['color'], label=label)

    # Target
    if target is not None:
        plt.scatter(target['RAJ2000'], target['DEJ2000'],
                    marker='*', s=300, color='gold', edgecolor='black',
                    linewidth=1.5, label='Target')

    # Etichette e legenda
    plt.xlabel('RA (deg)', fontsize=14)
    plt.ylabel('Dec (deg)', fontsize=14)
    plt.title(f'DBSCAN clustering (eps={eps}, min_samples={min_samples})', fontsize=16)
    plt.legend(loc='upper right', title='Legenda')
    plt.gca().set_facecolor('white')
    plt.gcf().set_facecolor('white')
    plt.grid(c="lightgray")
    plt.tight_layout()

    # Output testuale
    print(f"\nCluster del target: {target_cluster_id}")
    if target_cluster_id != -1:
        print(f"→ Numero membri nel cluster del target: {(labels == target_cluster_id).sum()}")
        print(f"→ Ellittiche nel cluster del target: {ellipses_in_target_cluster}")
    else:
        print("Il target è etichettato come rumore (cluster -1)")

    other_clusters = [cid for cid in clusters_with_ellipticals if cid != target_cluster_id]
    if other_clusters:
        print(f"Cluster con almeno un'ellittica (escluso il target): {other_clusters}")
    else:
        print("Nessun altro cluster contiene galassie ellittiche")

    return labels, main_cluster_mask if 'main_cluster_mask' in locals() else None

# %%
def iterative_dbscan(data, ellipticals, target, max_iter=5, eps_start=0.1, eps_step=0.01):
    data = data.copy()
    initial_data = data.copy()
    original_indices = data.index.copy()

    prev_count = 0
    best_labels = None
    best_cluster_mask = None
    best_indices = None  # Indici corrispondenti alla best_cluster_mask

    for i in range(max_iter):
        eps = eps_start

        # DBSCAN
        labels, cluster_mask = apply_dbscan(data, eps=eps, min_samples=5,
                                            ellipticals=ellipticals, target=target)

        current_count = cluster_mask.sum()

        # Salva risultato corrente come best
        best_labels = labels
        best_cluster_mask = cluster_mask
        best_indices = data.index.copy()

        # Condizioni di stop
        if abs(current_count - prev_count) / (prev_count + 1e-5) < 0.05:
            print(f"→ Convergenza raggiunta all’iterazione {i+1}")
            break
        if current_count > 0.7 * len(initial_data):
            print("→ Cluster troppo dominante. Stop.")
            break

        # Filtra per prossima iterazione (toglie rumore)
        data = data[labels != -1]
        prev_count = current_count
        eps_start += eps_step

    # Costruzione della maschera finale
    full_mask = pd.Series(False, index=initial_data.index)
    if best_cluster_mask is not None and best_indices is not None:
        # Prende solo gli indici dove cluster_mask è True
        member_indices = best_indices[best_cluster_mask]
        full_mask.loc[member_indices] = True

    return best_labels, full_mask.values

# %% [markdown]
# Usiamo tutti gli oggetti del campo

# %%
# Applica GMM con diversi numeri di componenti
n_components_range = range(2, 10)
bics, aics = [], []

# Prima filtraggio dei dati per evitare warning
clean_obj = all_objects[
    (all_objects['imag'].notna()) &
    (all_objects['rmag'].notna()) &
    (all_objects['imag'] > 0) &
    (all_objects['rmag'] > 0)
].copy()

# Ricrea X usato nel fit
X = np.column_stack([
    clean_obj['imag'],
    clean_obj['rmag'] - clean_obj['imag']
])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Trasforma anche il target nello stesso spazio
target_X = np.array([[target['imag'], target['rmag'] - target['imag']]])
target_X_scaled = scaler.transform(target_X)


for n in n_components_range:
    print(f"\nGMM con {n} componenti:")
    try:
        gmm, labels, probs, bic, aic, n_ell = fit_gmm(clean_obj, n_components=n, target=target, ellipticals=ellipticals)
        bics.append(bic)
        aics.append(aic)
    except Exception as e:
        print(f"Errore con {n} componenti: {str(e)}")
        bics.append(np.inf)
        aics.append(np.inf)

# Plot di BIC e AIC
plt.figure(figsize=(12, 6))
plt.plot(n_components_range, bics, 'o-', label='BIC', linewidth=2, markersize=10)
plt.plot(n_components_range, aics, 'o-', label='AIC', linewidth=2, markersize=10)

# Evidenzia il minimo per BIC
best_n_bic = n_components_range[np.argmin(bics)]
plt.axvline(x=best_n_bic, color='r', linestyle='--', alpha=0.5)
plt.text(best_n_bic+0.1, np.min(bics), f'n={best_n_bic}', color='r')

plt.xlabel('Numero di componenti', fontsize=14)
plt.ylabel('Valore del criterio', fontsize=14)
plt.title('Selezione del numero ottimale di componenti', fontsize=16)
plt.xticks(n_components_range)
plt.legend()
plt.grid(True)
plt.show()

# Selezione del modello migliore (BIC minimo)
best_n = best_n_bic
print(f"\nNumero ottimale di componenti (basato su BIC): {best_n}")



# Fit del modello finale con controllo
try:
    final_gmm, final_labels, final_probs, _, _, _= fit_gmm(
        clean_obj,
        n_components=best_n,
        target=target,
        ellipticals=ellipticals
    )

    # Identifica la componente che contiene l'oggetto target

    target_idx = clean_obj[clean_obj['SDSS9'] == target['SDSS9']].index[0]

    # Calcola le probabilità del target usando il GMM
    target_probs = final_gmm.predict_proba(target_X_scaled)
    red_sequence_idx = np.argmax(target_probs[0])


    # Seleziona membri con probabilità > 0.7 e statistiche
    cluster_mask = final_probs[:, red_sequence_idx] > 0.7
    cluster_members = clean_obj[cluster_mask]

    print("\nStatistiche del cluster:")
    print(f"- Numero membri: {len(cluster_members)}/{len(clean_obj)}")
    print(f"- Frazione: {len(cluster_members)/len(clean_obj):.2%}")
    print(f"- Colore medio (r-i): {np.mean(cluster_members['rmag'] - cluster_members['imag']):.2f}")
    print(f"- Magnitudine media (i): {np.mean(cluster_members['imag']):.2f}")


except Exception as e:
    print(f"\nErrore nel fitting finale: {str(e)}")
# Out:
# GMM con 2 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 34
# GMM con 3 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 32
# GMM con 4 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 28
# GMM con 5 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 27
# GMM con 6 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 21
# GMM con 7 componenti:
# → Ellittiche nel cluster del target (Cluster 6): 18
# GMM con 8 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 18
# GMM con 9 componenti:
# → Ellittiche nel cluster del target (Cluster 1): 20
# Numero ottimale di componenti (basato su BIC): 5
# → Ellittiche nel cluster del target (Cluster 1): 27
# Statistiche del cluster:
# - Numero membri: 350/3055
# - Frazione: 11.46%
# - Colore medio (r-i): 0.34
# - Magnitudine media (i): 16.77

# %%
# Fit del modello a 2 componenti che si trova in letteratura
gmm_2, labels_2, probs_2, _, _, _ = fit_gmm(all_objects, n_components=2, target=target, ellipticals=ellipticals)

# Ricrea le feature usate nel GMM
X = np.column_stack([
    all_objects['imag'],
    all_objects['rmag'] - all_objects['imag']
])

# Standardizza come nel fit_gmm
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Prepara e standardizza anche il target
target_X = np.array([[target['imag'], target['rmag'] - target['imag']]])
target_X_scaled = scaler.transform(target_X)

# Calcola le probabilità del target
target_probs_2 = gmm_2.predict_proba(target_X_scaled)
red_sequence_idx_2 = np.argmax(target_probs_2[0])


# Seleziona membri del cluster
cluster_mask_2 = probs_2[:, red_sequence_idx_2] > 0.7
cluster_members_2 = all_objects[cluster_mask_2]

print(f"\nNumero di membri del cluster con GMM a 2 componenti: {len(cluster_members_2)}")

# Confronto visivo
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot del modello ottimale
plot_cmd(all_objects, "GMM ottimale", ax1, color='gray')
plot_cmd(cluster_members, f"Cluster (n={len(cluster_members)})", ax1, color='red')

# Plot del modello a 2 componenti
plot_cmd(all_objects, "GMM a 2 componenti", ax2, color='gray')
plot_cmd(cluster_members_2, f"Cluster (n={len(cluster_members_2)})", ax2, color='red')

plt.show()
# Out:
# → Ellittiche nel cluster del target (Cluster 1): 34
# Numero di membri del cluster con GMM a 2 componenti: 832

# %%
#Applicazione di DBSCAN su coordinate fisiche

dbscan_labels, main_cluster_mask = apply_dbscan(all_objects, eps=0.07, min_samples=5,
                             ellipticals=ellipticals, target=target, show_redshifts=False)
# Out:
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 31
# → Numero membri nel cluster del target: 199
# → Ellittiche nel cluster del target: 11
# Cluster con almeno un'ellittica (escluso il target): [np.int64(10), np.int64(22), np.int64(28), np.int64(33), np.int64(36), np.int64(38), np.int64(44), np.int64(50), np.int64(66), np.int64(74), np.int64(80), np.int64(106), np.int64(117), np.int64(120), np.int64(122), np.int64(144)]

# %%
#Applicazione iterativa del DBSCAN per selezionare i core points più significativi e avere meno clusters
dbscan_labels, main_cluster_mask = iterative_dbscan(all_objects, ellipticals, target, max_iter=10, eps_start=0.05, eps_step=0.01)
# Out:
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 45
# → Numero membri nel cluster del target: 4
# → Ellittiche nel cluster del target: 1
# Cluster con almeno un'ellittica (escluso il target): [np.int64(16), np.int64(19), np.int64(25), np.int64(34), np.int64(38), np.int64(39), np.int64(40), np.int64(46), np.int64(78)]
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 33
# → Numero membri nel cluster del target: 42
# → Ellittiche nel cluster del target: 7
# Cluster con almeno un'ellittica (escluso il target): [np.int64(15), np.int64(18), np.int64(30), np.int64(34), np.int64(39), np.int64(70)]
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 27
# → Numero membri nel cluster del target: 71
# → Ellittiche nel cluster del target: 7
# Cluster con almeno un'ellittica (escluso il target): [np.int64(15), np.int64(17), np.int64(28), np.int64(31), np.int64(60)]
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 26
# → Numero membri nel cluster del target: 102
# → Ellittiche nel cluster del target: 9
# Cluster con almeno un'ellittica (escluso il target): [np.int64(14), np.int64(16), np.int64(29), np.int64(58)]
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 23
# → Numero membri nel cluster del target: 102
# → Ellittiche nel cluster del target: 9
# Cluster con almeno un'ellittica (escluso il target): [np.int64(11), np.int64(14), np.int64(26), np.int64(54)]
# → Convergenza raggiunta all’iterazione 5

# %%
#Validazione con Redshift Spettroscopici


# Carica i redshift spettroscopici (se disponibili)
try:
    z_spec = all_objects['zsp'].values
    z_spec_2 = galaxies['zsp'].values
    has_z_spec = ~np.isnan(z_spec)
    has_z_spec_2 = ~np.isnan(z_spec_2)


    # Definisce i veri membri (entro delta_z < 0.005 dalla RG)
    true_members = np.abs(z_spec - z_RG) < 0.005

    # Confronta con i risultati del clustering
    gmm_predicted = np.zeros_like(true_members, dtype=bool)
    gmm_predicted[cluster_mask] = True

    dbscan_predicted = np.zeros_like(true_members, dtype=bool)
    dbscan_predicted[main_cluster_mask] = True

    # Metriche di performance
    def print_metrics(true, pred, method):
        cm = confusion_matrix(true, pred)
        precision = precision_score(true, pred)
        recall = recall_score(true, pred)

        print(f"\nMetriche per {method}:")
        print(f"Matrice di confusione:\n{cm}")
        print(f"Precision: {precision:.3f}")
        print(f"Recall: {recall:.3f}")
        print(f"Purezza: {cm[1,1]/(cm[0,1]+cm[1,1]):.3f}")
        print(f"Completezza: {cm[1,1]/(cm[1,0]+cm[1,1]):.3f}")

    print_metrics(true_members, gmm_predicted, "GMM")
    print_metrics(true_members, dbscan_predicted, "DBSCAN")




    # Plot dei redshift
    plt.figure(figsize=(12, 6))
    z_min, z_max = np.nanmin(z_spec), 0.8  #estremi del plot
    bin_width = 0.01
    bins = np.arange(z_min, z_max + bin_width, bin_width)

    plt.hist(z_spec[has_z_spec], bins=bins, alpha=0.7, label='Tutti')
    plt.hist(z_spec[gmm_predicted & has_z_spec], bins=bins, alpha=0.7, label='GMM')
    plt.hist(z_spec[dbscan_predicted & has_z_spec], bins=bins, alpha=0.7, label='DBSCAN')
    plt.hist(z_spec_2[has_z_spec_2], bins=bins, alpha=0.7, label='Galassie ellittiche')



    plt.axvline(x=z_RG, color='r', linestyle='--', label='Radiogalassia')
    plt.xlabel('Redshift', fontsize=14)
    plt.ylabel('Conteggio', fontsize=14)
    plt.title('Distribuzione dei redshift', fontsize=16)
    plt.legend()
    plt.grid(True)
    plt.show()

except KeyError:
    print("Nessun dato di redshift spettroscopico disponibile per la validazione.")
# Out:
# Metriche per GMM:
# Matrice di confusione:
# [[2703  334]
#  [   2   16]]
# Precision: 0.046
# Recall: 0.889
# Purezza: 0.046
# Completezza: 0.889
#
# Metriche per DBSCAN:
# Matrice di confusione:
# [[2940   97]
#  [  13    5]]
# Precision: 0.049
# Recall: 0.278
# Purezza: 0.049
# Completezza: 0.278

# %%
# Approccio Ibrido combinando GMM nel CMD e DBSCAN in RA/Dec per una selezione più robusta.
print("\nApproccio ibrido: GMM + DBSCAN")

# Prende i candidati dal GMM
gmm_candidates = all_objects[cluster_mask]

# Applica DBSCAN a questi candidati
hybrid_labels, tmp = apply_dbscan(gmm_candidates, eps=0.09, min_samples=3, ellipticals=ellipticals, target=target, show_redshifts=True)

# Gestione del caso in cui DBSCAN non trova cluster
if len(np.unique(hybrid_labels[hybrid_labels != -1])) == 0:
    print("DBSCAN non ha trovato cluster - usando tutti i candidati GMM")
    hybrid_members = gmm_candidates
else:
    # Trova l’indice del target nel DataFrame gmm_candidates
    try:
      target_idx_hybrid = gmm_candidates[gmm_candidates['SDSS9'] == target['SDSS9']].index[0]
      target_cluster_id = hybrid_labels[gmm_candidates.index.get_loc(target_idx_hybrid)]

      if target_cluster_id == -1:
          print("Il target è considerato rumore da DBSCAN nell'approccio ibrido.")
          hybrid_members = gmm_candidates.iloc[[]]  # Vuoto
      else:
          # Seleziona solo il cluster che contiene il target
          hybrid_cluster_mask = hybrid_labels == target_cluster_id
          hybrid_members = gmm_candidates[hybrid_cluster_mask]

    except IndexError:
      print("Il target non è stato trovato tra i candidati GMM.")
      hybrid_members = gmm_candidates.iloc[[]]  # Vuoto

print(f"Numero di membri con approccio ibrido: {len(hybrid_members)}")
# Out:
# Approccio ibrido: GMM + DBSCAN
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 12
# → Numero membri nel cluster del target: 7
# → Ellittiche nel cluster del target: 3
# Cluster con almeno un'ellittica (escluso il target): [np.int64(4), np.int64(6), np.int64(7), np.int64(10), np.int64(11), np.int64(13), np.int64(17), np.int64(19), np.int64(22)]
# Numero di membri con approccio ibrido: 7

# %%
# Validazione con redshift spettroscopici per l'approccio ibrido
try:
    hybrid_predicted = np.zeros_like(true_members, dtype=bool)
    hybrid_predicted[hybrid_members.index] = True

    print_metrics(true_members, hybrid_predicted, "Approccio Ibrido")

    # Aggiungi l'istogramma anche per l'approccio ibrido
    plt.figure(figsize=(12, 6))
    z_min, z_max = 0., 0.8
    bin_width = 0.005
    bins = np.arange(z_min, z_max + bin_width, bin_width)

    plt.hist(z_spec[has_z_spec], bins=bins, alpha=0.7, label='Tutti')
    plt.hist(z_spec[gmm_predicted & has_z_spec], bins=bins, alpha=0.7, label='GMM')
    plt.hist(z_spec[dbscan_predicted & has_z_spec], bins=bins, alpha=0.7, label='DBSCAN')
    plt.hist(z_spec[hybrid_predicted & has_z_spec], bins=30, alpha=0.7, label='Ibrido')

    plt.axvline(x=z_RG, color='r', linestyle='--', label='Radiogalassia')
    plt.xlabel('Redshift', fontsize=14)
    plt.ylabel('Conteggio', fontsize=14)
    plt.title('Distribuzione dei redshift (con metodo ibrido)', fontsize=16)
    plt.legend()
    plt.grid(True)
    plt.show()

except Exception as e:
    print(f"\nErrore durante la validazione dell’approccio ibrido: {e}")
# Out:
# Metriche per Approccio Ibrido:
# Matrice di confusione:
# [[3030    7]
#  [  18    0]]
# Precision: 0.000
# Recall: 0.000
# Purezza: 0.000
# Completezza: 0.000

# %% [markdown]
# Usiamo il file con solo le galassie

# %%
# Applica GMM con diversi numeri di componenti
n_components_range = range(2, 11)
bics, aics = [], []

# Prima filtraggio dei dati per evitare warning
clean_galaxies = galaxies[
    (galaxies['imag'].notna()) &
    (galaxies['rmag'].notna()) &
    (galaxies['imag'] > 0) &
    (galaxies['rmag'] > 0)
].copy()

# Ricrea X usato nel fit
X = np.column_stack([
    clean_galaxies['imag'],
    clean_galaxies['rmag'] - clean_galaxies['imag']
])

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Trasforma anche il target nello stesso spazio
target_X = np.array([[target['imag'], target['rmag'] - target['imag']]])
target_X_scaled = scaler.transform(target_X)


for n in n_components_range:
    print(f"\nGMM con {n} componenti:")
    try:
        gmm, labels, probs, bic, aic, ell_n = fit_gmm(clean_galaxies, n_components=n, target=target, ellipticals=ellipticals)
        bics.append(bic)
        aics.append(aic)
    except Exception as e:
        print(f"Errore con {n} componenti: {str(e)}")
        bics.append(np.inf)
        aics.append(np.inf)

# Plot di BIC e AIC
plt.figure(figsize=(12, 6))
plt.plot(n_components_range, bics, 'o-', label='BIC', linewidth=2, markersize=10)
plt.plot(n_components_range, aics, 'o-', label='AIC', linewidth=2, markersize=10)

# Evidenzia il minimo per BIC
best_n_bic = n_components_range[np.argmin(bics)]
plt.axvline(x=best_n_bic, color='r', linestyle='--', alpha=0.5)
plt.text(best_n_bic+0.1, np.min(bics), f'n={best_n_bic}', color='r')

plt.xlabel('Number of components', fontsize=14)
plt.ylabel('Criteria value', fontsize=14)
plt.title('BIC & AIC trends', fontsize=16)
plt.xticks(n_components_range)
plt.legend()
plt.gca().set_facecolor('white')
plt.gcf().set_facecolor('white')
plt.grid(c = 'lightgray')
plt.show()

# Selezione del modello migliore (BIC minimo)
best_n = best_n_bic
print(f"\nNumero ottimale di componenti (basato su BIC): {best_n}")

# Fit del modello finale con controllo
try:
    final_gmm, final_labels, final_probs, _, _, _ = fit_gmm(
        clean_galaxies,
        n_components=best_n,
        target=target,
        ellipticals=ellipticals
    )

    # Identifica la componente che contiene l'oggetto target
    target_idx = clean_galaxies[clean_galaxies['SDSS9'] == target['SDSS9']].index[0]
    # Calcola le probabilità del target usando il GMM
    target_probs = final_gmm.predict_proba(target_X_scaled)
    red_sequence_idx = np.argmax(target_probs[0])


    # Seleziona membri con probabilità > 0.7 e statistiche
    cluster_mask = final_probs[:, red_sequence_idx] > 0.7
    cluster_members = clean_galaxies[cluster_mask]

    print("\nStatistiche del cluster:")
    print(f"- Numero membri: {len(cluster_members)}/{len(clean_galaxies)}")
    print(f"- Frazione: {len(cluster_members)/len(clean_galaxies):.2%}")
    print(f"- Colore medio (r-i): {np.mean(cluster_members['rmag'] - cluster_members['imag']):.2f}")
    print(f"- Magnitudine media (i): {np.mean(cluster_members['imag']):.2f}")

except Exception as e:
    print(f"\nErrore nel fitting finale: {str(e)}")
# Out:
# GMM con 2 componenti:
# → Ellittiche nel cluster del target (Cluster 0): 36
# GMM con 3 componenti:
# → Ellittiche nel cluster del target (Cluster 0): 36
# GMM con 4 componenti:
# → Ellittiche nel cluster del target (Cluster 0): 32
# GMM con 5 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# GMM con 6 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# GMM con 7 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# GMM con 8 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# GMM con 9 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# GMM con 10 componenti:
# → Ellittiche nel cluster del target (Cluster 4): 22
# Numero ottimale di componenti (basato su BIC): 5
# → Ellittiche nel cluster del target (Cluster 4): 22
# Statistiche del cluster:
# - Numero membri: 40/819
# - Frazione: 4.88%
# - Colore medio (r-i): 0.46
# - Magnitudine media (i): 17.12

# %%
# Fit del modello a 2 componenti
gmm_2, labels_2, probs_2, _, _, _ = fit_gmm(galaxies, n_components=2, target=target,  ellipticals=ellipticals)

# Ricrea le feature usate nel GMM
X = np.column_stack([
    galaxies['imag'],
    galaxies['rmag'] - galaxies['imag']
])

# Standardizza come nel fit_gmm
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Prepara e standardizza anche il target
target_X = np.array([[target['imag'], target['rmag'] - target['imag']]])
target_X_scaled = scaler.transform(target_X)

# Calcola le probabilità del target
target_probs_2 = gmm_2.predict_proba(target_X_scaled)
red_sequence_idx_2 = np.argmax(target_probs_2[0])


# Seleziona membri del cluster
cluster_mask_2 = probs_2[:, red_sequence_idx_2] > 0.7
cluster_members_2 = galaxies[cluster_mask_2]

print(f"\nNumero di membri del cluster con GMM a 2 componenti: {len(cluster_members_2)}")

# Confronto visivo
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot del modello ottimale
plot_cmd(galaxies, "GMM ottimale", ax1, color='gray')
plot_cmd(cluster_members, f"Cluster (n={len(cluster_members)})", ax1, color='red')

# Plot del modello a 2 componenti
plot_cmd(galaxies, "GMM a 2 componenti", ax2, color='gray')
plot_cmd(cluster_members_2, f"Cluster (n={len(cluster_members_2)})", ax2, color='red')

plt.show()
# Out:
# → Ellittiche nel cluster del target (Cluster 0): 36
# Numero di membri del cluster con GMM a 2 componenti: 341

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

def plot_gmm_cluster_members_spatial(cluster_members, target=None, ellipticals=None, show_redshifts=True):
    """Plot dei membri del cluster GMM selezionato, con RA/Dec, ellittiche e redshift."""
    plt.figure(figsize=(12, 10))

    # Punti base (cluster members)
    plt.scatter(cluster_members['RAJ2000'], cluster_members['DEJ2000'],
                s=20, alpha=0.6, color='steelblue', label='Cluster members')

    # Ellittiche
    if ellipticals is not None:
        ell_mask = cluster_members['SDSS9'].isin(ellipticals['SDSS9'])
        if ell_mask.any():
            plt.scatter(cluster_members['RAJ2000'][ell_mask], cluster_members['DEJ2000'][ell_mask],
                        s=60, alpha=0.9, marker='o',
                        edgecolor='black', linewidths=1.2,
                        facecolor='orange', label='Ellipticals')

    # Redshift labels
    if show_redshifts and 'zsp' in cluster_members.columns:
        texts = []
        zmask = cluster_members['zsp'].notna()
        for idx in cluster_members[zmask].index:
            ra = cluster_members.at[idx, 'RAJ2000']
            dec = cluster_members.at[idx, 'DEJ2000']
            z = cluster_members.at[idx, 'zsp']
            texts.append(plt.text(ra, dec, f"{z:.3f}", fontsize=10, color='darkgray'))
        adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))

    # Target
    if target is not None:
        plt.scatter(target['RAJ2000'], target['DEJ2000'],
                    marker='*', s=300, color='gold', edgecolor='black',
                    linewidth=1.5, label='Target')

    # Dettagli del grafico
    plt.xlabel("Ra (deg)", fontsize=14)
    plt.ylabel("Dec (deg)", fontsize=14)
    plt.title("Spatial distribution of main cluster members", fontsize=16)
    plt.legend(loc='best')
    plt.grid(c="lightgray")
    plt.gca().set_facecolor('white')
    plt.gcf().set_facecolor('white')
    plt.tight_layout()
    plt.show()

# Applica la funzione
plot_gmm_cluster_members_spatial(cluster_members, target=target, ellipticals=ellipticals, show_redshifts=True)

# %%
#Applicazione di DBSCAN

dbscan_labels, main_cluster_mask = apply_dbscan(galaxies, eps=0.12, min_samples=3,
                             ellipticals=ellipticals, target=target)
# Out:
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 22
# → Numero membri nel cluster del target: 96
# → Ellittiche nel cluster del target: 14
# Cluster con almeno un'ellittica (escluso il target): [np.int64(8), np.int64(20), np.int64(23), np.int64(24), np.int64(25), np.int64(32), np.int64(38), np.int64(40), np.int64(43), np.int64(50), np.int64(53), np.int64(57), np.int64(58)]

# %%
#Approccio iterativo
dbscan_labels, main_cluster_mask = iterative_dbscan(galaxies, ellipticals, target, max_iter=10, eps_start=0.11, eps_step=0.01)
# Out:
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 14
# → Numero membri nel cluster del target: 52
# → Ellittiche nel cluster del target: 11
# Cluster con almeno un'ellittica (escluso il target): [np.int64(7), np.int64(9), np.int64(13), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(21), np.int64(28), np.int64(33), np.int64(35), np.int64(36), np.int64(42)]
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 14
# → Numero membri nel cluster del target: 50
# → Ellittiche nel cluster del target: 11
# Cluster con almeno un'ellittica (escluso il target): [np.int64(8), np.int64(13), np.int64(15), np.int64(16), np.int64(17), np.int64(20), np.int64(27), np.int64(32), np.int64(34), np.int64(35), np.int64(40)]
# → Convergenza raggiunta all’iterazione 2

# %%
# Carica i redshift spettroscopici (se disponibili)
try:
    z_spec = galaxies['zsp'].values
    has_z_spec = ~np.isnan(z_spec)

    # Definisce i veri membri (entro delta_z < 0.005 dalla RG
    true_members = np.abs(z_spec - z_RG) < 0.005

    # Confronta con i risultati del clustering
    gmm_predicted = np.zeros_like(true_members, dtype=bool)
    gmm_predicted[cluster_mask] = True

    dbscan_predicted = np.zeros_like(true_members, dtype=bool)
    dbscan_predicted[main_cluster_mask] = True

    # Metriche di performance
    def print_metrics(true, pred, method):
        cm = confusion_matrix(true, pred)
        precision = precision_score(true, pred)
        recall = recall_score(true, pred)

        print(f"\nMetriche per {method}:")
        print(f"Matrice di confusione:\n{cm}")
        print(f"Precision: {precision:.3f}")
        print(f"Recall: {recall:.3f}")
        print(f"Purezza: {cm[1,1]/(cm[0,1]+cm[1,1]):.3f}")
        print(f"Completezza: {cm[1,1]/(cm[1,0]+cm[1,1]):.3f}")

    print_metrics(true_members, gmm_predicted, "GMM")




    # Plot dei redshift
    plt.figure(figsize=(12, 6))
    z_min, z_max = np.nanmin(z_spec), 0.13
    bin_width = 0.0025
    bins = np.arange(z_min, z_max + bin_width, bin_width)

    plt.hist(z_spec[has_z_spec], bins=bins, alpha=0.7, label='All')
    plt.hist(z_spec[gmm_predicted & has_z_spec], bins=bins, alpha=0.7, label='GMM')

    plt.axvline(x=z_RG, color='r', linestyle='--', label='Radiogalaxy')
    plt.xlabel('Redshift', fontsize=14)
    plt.ylabel('Counts', fontsize=14)
    plt.title('Spectroscopic z distribution ', fontsize=16)
    plt.legend()
    plt.gca().set_facecolor('white')
    plt.gcf().set_facecolor('white')
    plt.grid(c = 'lightgray')
    plt.show()

except KeyError:
    print("Nessun dato di redshift spettroscopico disponibile per la validazione.")
# Out:
# Metriche per GMM:
# Matrice di confusione:
# [[778  25]
#  [  1  15]]
# Precision: 0.375
# Recall: 0.938
# Purezza: 0.375
# Completezza: 0.938

# %%
def plot_confusion_matrix_with_custom_colors(true, pred, method_name="GMM"):
    # Calcolo metriche
    cm = confusion_matrix(true, pred)
    precision = precision_score(true, pred)
    recall = recall_score(true, pred)
    purity = cm[1, 1] / (cm[0, 1] + cm[1, 1]) if (cm[0, 1] + cm[1, 1]) > 0 else 0
    completeness = cm[1, 1] / (cm[1, 0] + cm[1, 1]) if (cm[1, 0] + cm[1, 1]) > 0 else 0

    labels = np.array([["TN", "FP"], ["FN", "TP"]])  # per reference
    annot = np.empty_like(cm).astype(str)
    for i in range(2):
        for j in range(2):
            annot[i, j] = f"{cm[i, j]}\n({labels[i, j]})"

    # Definizione dei colori personalizzati con trasparenza (alpha=0.7)
    colors = [
        [[0.0, 0.0, 0.8, 0.7], [0.55, 0.0, 0.0, 0.7]],   # TN, FP
        [[1.0, 0.5, 0.5, 0.7], [0.53, 0.81, 0.92, 0.7]]        # FN, TP
    ]

    fig = plt.figure(figsize=(8, 10))
    gs = fig.add_gridspec(2, 1, height_ratios=[3, 1])

    # Matrice di confusione come rettangoli colorati
    ax0 = fig.add_subplot(gs[0])

    # Disegna i rettangoli colorati senza bordi
    for i in range(2):
        for j in range(2):
            rect = plt.Rectangle((j-0.5, i-0.5), 1, 1,
                                facecolor=colors[i][j],
                                edgecolor='none')  # Nessun bordo
            ax0.add_patch(rect)

    # Aggiungi annotazioni
    for i in range(2):
        for j in range(2):
            ax0.text(j, i, annot[i, j], ha="center", va="center", color="white", fontsize=30 )

    # Configurazione degli assi
    ax0.set_xlim(-0.5, 1.5)
    ax0.set_ylim(-0.5, 1.5)
    ax0.set_xticks([0, 1])
    ax0.set_yticks([0, 1])
    ax0.set_xticklabels(["Not Member", "Member"])
    ax0.set_yticklabels(["Not Member", "Member"])
    ax0.set_xlabel("Predicted", fontsize=12)
    ax0.set_ylabel("True", fontsize=12)
    ax0.set_title(f"Confusion Matrix - {method_name}", fontsize=14)
    ax0.invert_yaxis()  # Per mantenere l'ordine TN, FP in alto

    # Fascia sottostante con metriche
    ax1 = fig.add_subplot(gs[1])
    ax1.axis("off")
    cell_text = [
        [f"{purity:.3f}", f"{completeness:.3f}"]
    ]
    col_labels = ["Purity", "Completeness"]
    table = ax1.table(cellText=cell_text, colLabels=col_labels,
                      loc='center', cellLoc='center', colColours=["#d0e4f5"]*4)
    table.scale(1, 2)
    table.set_fontsize(12)

    fig.patch.set_facecolor("white")
    plt.tight_layout()
    plt.show()

plot_confusion_matrix_with_custom_colors(true_members, gmm_predicted, method_name="GMM")

# %%
# Modello ibrido: GMM in CMD seguito da DBSCAN in RA/Dec
print("\nApproccio ibrido 1: GMM + DBSCAN")

#  Candidati dal GMM
gmm_candidates = galaxies[cluster_mask]

# Applica DBSCAN a questi candidati
hybrid_labels, tmp = apply_dbscan(gmm_candidates, eps=0.4, min_samples=3, ellipticals=ellipticals, target=target, show_redshifts=True)

# Gestione del caso in cui DBSCAN non trova cluster
if len(np.unique(hybrid_labels[hybrid_labels != -1])) == 0:
    print("DBSCAN non ha trovato cluster - usando tutti i candidati GMM")
    hybrid_members = gmm_candidates
else:
    # Trova l’indice del target nel DataFrame gmm_candidates
    try:
      target_idx_hybrid = gmm_candidates[gmm_candidates['SDSS9'] == target['SDSS9']].index[0]
      target_cluster_id = hybrid_labels[gmm_candidates.index.get_loc(target_idx_hybrid)]

      if target_cluster_id == -1:
          print("Il target è considerato rumore da DBSCAN nell'approccio ibrido.")
          hybrid_members = gmm_candidates.iloc[[]]  # Vuoto
      else:
          # Seleziona solo il cluster che contiene il target
          hybrid_cluster_mask = hybrid_labels == target_cluster_id
          hybrid_members = gmm_candidates[hybrid_cluster_mask]

    except IndexError:
      print("Il target non è stato trovato tra i candidati GMM.")
      hybrid_members = gmm_candidates.iloc[[]]  # Vuoto

print(f"Numero di membri con approccio ibrido: {len(hybrid_members)}")
# Out:
# Approccio ibrido 1: GMM + DBSCAN
# /tmp/ipython-input-30-1081514142.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('nipy_spectral', 256)
# Cluster del target: 0
# → Numero membri nel cluster del target: 16
# → Ellittiche nel cluster del target: 13
# Cluster con almeno un'ellittica (escluso il target): [np.int64(1), np.int64(2)]
# Numero di membri con approccio ibrido: 16

# %%
# Validazione con redshift spettroscopici per l'approccio ibrido
try:
    hybrid_predicted = np.zeros_like(true_members, dtype=bool)
    hybrid_predicted[hybrid_members.index] = True

    print_metrics(true_members, hybrid_predicted, "Approccio Ibrido")

    # Aggiungi l'istogramma anche per l'approccio ibrido
    plt.figure(figsize=(12, 6))
    z_min, z_max = np.nanmin(z_spec), 0.14
    bin_width = 0.0025
    bins = np.arange(z_min, z_max + bin_width, bin_width)

    plt.hist(z_spec[has_z_spec], bins=bins, alpha=0.7, label='Tutti')
    plt.hist(z_spec[gmm_predicted & has_z_spec], bins=bins, alpha=0.7, label='GMM')
    plt.hist(z_spec[dbscan_predicted & has_z_spec], bins=bins, alpha=0.7, label='DBSCAN')
    plt.hist(z_spec[hybrid_predicted & has_z_spec], bins=30, alpha=0.7, label='Ibrido')

    plt.axvline(x=z_RG, color='r', linestyle='--', label='Radiogalassia')
    plt.xlabel('Redshift', fontsize=14)
    plt.ylabel('Conteggio', fontsize=14)
    plt.title('Distribuzione dei redshift (con metodo ibrido)', fontsize=16)
    plt.legend()
    plt.grid(True)
    plt.show()

except Exception as e:
    print(f"\nErrore durante la validazione dell’approccio ibrido: {e}")
# Out:
# Metriche per Approccio Ibrido:
# Matrice di confusione:
# [[794   9]
#  [  9   7]]
# Precision: 0.438
# Recall: 0.438
# Purezza: 0.438
# Completezza: 0.438

# %%
plot_confusion_matrix_with_custom_colors(true_members, hybrid_predicted, method_name="Hybrid")

# %%
"""
## Risultati Finali e Conclusioni

Sintetizziamo i risultati dei diversi approcci:
"""

# Tabella riassuntiva
results = pd.DataFrame({
    'Metodo': ['GMM ottimale', 'GMM 2 componenti', 'DBSCAN', 'GMM+DBSCAN'],
    'N_membri': [
        len(cluster_members),
        len(cluster_members_2),
        len(main_cluster_mask),
        len(hybrid_members),
    ]
})

print("\nRisultati comparativi:")
display(results)

# Salva i risultati
cluster_members.to_csv('membri_cluster_gmm.csv', index=False)
hybrid_members.to_csv('membri_cluster_ibrido.csv', index=False)



"""
## Conclusioni

1. Il metodo GMM nel diagramma CMD è efficace per identificare la red sequence.
2. L'approccio ibrido (GMM + DBSCAN) fornisce una selezione più pulita combinando informazioni fotometriche e spaziali.
4. La validazione con redshift spettroscopici è cruciale per valutare la qualità della selezione.

Per ulteriori analisi:
- Sperimentare con diversi parametri per DBSCAN
- Provare altri algoritmi di clustering (es. HDBSCAN)
- Includere altre bande fotometriche per migliorare la separazione
"""
# Out:
# Risultati comparativi:
#              Metodo  N_membri
# 0      GMM ottimale        40
# 1  GMM 2 componenti       341
# 2            DBSCAN       819
# 3        GMM+DBSCAN        16
# "\n## Conclusioni\n\n1. Il metodo GMM nel diagramma CMD è efficace per identificare la red sequence.\n2. L'approccio ibrido (GMM + DBSCAN) fornisce una selezione più pulita combinando informazioni fotometriche e spaziali.\n4. La validazione con redshift spettroscopici è cruciale per valutare la qualità della selezione.\n\nPer ulteriori analisi:\n- Sperimentare con diversi parametri per DBSCAN\n- Provare altri algoritmi di clustering (es. HDBSCAN)\n- Includere altre bande fotometriche per migliorare la separazione\n"

# %% [markdown]
# Faccio un taglio sulla magnitudine

# %%
#Taglia gli oggetti che hanno una magnitudine maggiore di quella del target + 3
i_cut = target['imag']+3

print(f"Taglio sulla magnitudine a {i_cut}")
# Out:
# Taglio sulla magnitudine a 20.0939998626709

# %%
# Applica GMM con diversi numeri di componenti
n_components_range = range(2, 10)
bics, aics = [], []

# Prima filtraggio dei dati per evitare warning
magn_cut = all_objects[
    (all_objects['imag'].notna()) &
    (all_objects['rmag'].notna()) &
    (all_objects['imag'] > 0) &
    (all_objects['rmag'] > 0) &
    (all_objects['imag'] < i_cut)
].copy()

# Ricrea X usato nel fit
X = np.column_stack([
    magn_cut['imag'],
    magn_cut['rmag'] - magn_cut['imag']
])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Trasforma anche il target nello stesso spazio
target_X = np.array([[target['imag'], target['rmag'] - target['imag']]])
target_X_scaled = scaler.transform(target_X)



final_gmm, final_labels, final_probs, _, _, _ = fit_gmm(
  magn_cut,
  n_components=2,
  target=target,
  ellipticals=ellipticals
  )

# Identifica la componente che contiene l'oggetto target
# Prima troviamo l'indice del target nel dataframe clean_galaxies
target_idx = magn_cut[magn_cut['SDSS9'] == target['SDSS9']].index[0]
# Poi troviamo la componente a cui appartiene (quella con probabilità massima)
# Calcola le probabilità del target usando il GMM
target_probs = final_gmm.predict_proba(target_X_scaled)
red_sequence_idx = np.argmax(target_probs[0])


# Seleziona membri con probabilità > 0.7 e statistiche
cluster_mask = final_probs[:, red_sequence_idx] > 0.7
cluster_members = magn_cut[cluster_mask]

print("\nStatistiche del cluster:")
print(f"- Numero membri: {len(cluster_members)}/{len(magn_cut)}")
print(f"- Frazione: {len(cluster_members)/len(magn_cut):.2%}")
print(f"- Colore medio (r-i): {np.mean(cluster_members['rmag'] - cluster_members['imag']):.2f}")
print(f"- Magnitudine media (i): {np.mean(cluster_members['imag']):.2f}")
# Out:
# → Ellittiche nel cluster del target (Cluster 0): 26
# Statistiche del cluster:
# - Numero membri: 333/1207
# - Frazione: 27.59%
# - Colore medio (r-i): 0.35
# - Magnitudine media (i): 16.60

# %%
def plot_k_distance_graph(data, k=5, scale=True):
    """
    Plot the k-distance graph (metodo dell'elbow) per DBSCAN.

    Parametri:
    - data: DataFrame con colonne 'RAJ2000' e 'DEJ2000'
    - k: numero di vicini (tipicamente = min_samples)
    - scale: se True, standardizza le coordinate prima di calcolare le distanze

    Output:
    - mostra il grafico delle k-distanze ordinate
    - ritorna array delle distanze
    """
    coords = data[['RAJ2000', 'DEJ2000']].values

    if scale:
        coords = StandardScaler().fit_transform(coords)

    # Calcola distanze ai k vicini
    neigh = NearestNeighbors(n_neighbors=k)
    neigh.fit(coords)
    distances, _ = neigh.kneighbors(coords)

    # Prende solo la distanza al k-esimo vicino
    k_distances = distances[:, k-1]
    k_distances = np.sort(k_distances)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(k_distances)
    plt.xlabel(f'Dati ordinati')
    plt.ylabel(f'Distanza al {k}° vicino')
    plt.title('K-distance graph per scelta di eps')
    plt.grid(True)
    plt.show()

    return k_distances


def find_elbow_point(k_distances):
    from scipy.spatial.distance import euclidean
    from numpy.linalg import norm

    n_points = len(k_distances)
    all_indices = np.arange(n_points)

    # Punto iniziale e finale della curva
    start = np.array([0, k_distances[0]])
    end = np.array([n_points - 1, k_distances[-1]])

    # Calcola la distanza di ogni punto dalla linea retta (start-end)
    distances = []
    for i in range(n_points):
        point = np.array([i, k_distances[i]])
        distance = norm(np.cross(end - start, start - point)) / norm(end - start)
        distances.append(distance)

    elbow_index = np.argmax(distances)
    elbow_eps = k_distances[elbow_index]

    return elbow_eps, elbow_index

# %%
k_distances = plot_k_distance_graph(galaxies, k=5)
eps, idx = find_elbow_point(k_distances)
print(f"Valore consigliato di eps: {eps:.3f} (indice {idx})")
# Out:
# Valore consigliato di eps: 0.200 (indice 739)
# /tmp/ipython-input-53-3848790000.py:55: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   distance = norm(np.cross(end - start, start - point)) / norm(end - start)
